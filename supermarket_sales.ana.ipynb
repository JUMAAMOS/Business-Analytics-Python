# 64.36
# 89.75
# 97.16
# 87.87
# 12.45
# 52.75
# 82.7
# 48.71
# 78.55
# 23.07
# 58.26
# 30.35
# 88.67
# 27.38
# 62.13
# 33.98
# 81.97
# 16.49
# 98.21
# 72.84
# 58.07
# 80.79
# 27.02
# 21.94
# 51.36
# 10.96
# 53.44
# 99.56
# 57.12
# 99.96
# 63.91
# 56.47
# ...

# %%
df.Unitprice.max()
# Out:
# 99.96

# %%
df.Unitprice.count()
# Out:
# 1000

# %%
df.Unitprice.min()
# Out:
# 10.08

# %%
df.groupby('Unitprice').count()
# Out:
#            No  InvoiceID  Branch  City  Customertype  Gender  Productline  \
# Unitprice
# 10.08       1          1       1     1             1       1            1
# 10.13       1          1       1     1             1       1            1
# 10.16       1          1       1     1             1       1            1
# 10.17       1          1       1     1             1       1            1
# 10.18       1          1       1     1             1       1            1
# ...        ..        ...     ...   ...           ...     ...          ...
# 99.82       2          2       2     2             2       2            2
# 99.83       1          1       1     1             1       1            1
# 99.89       1          1       1     1             1       1            1
# 99.92       1          1       1     1             1       1            1
# 99.96       2          2       2     2             2       2            2
#
#            Quantity  Tax  Total  Date  Time  Payment  cogs  \
# ...

# %%
df.groupby('Gender').count()
# Out:
#          No  InvoiceID  Branch  City  Customertype  Productline  Unitprice  \
# Gender
# Female  501        501     501   501           501          501        501
# Male    499        499     499   499           499          499        499
#
#         Quantity  Tax  Total  Date  Time  Payment  cogs  \
# Gender
# Female       501  501    501   501   501      501   501
# Male         499  499    499   499   499      499   499
#
#         gross_margin_percentage  gross_iincome  Rating
# Gender
# Female                      501            501     501
# Male                        499            499     499

# %%
df.groupby('Gender').max()
# Out:
#           No    InvoiceID Branch    City Customertype        Productline  \
# Gender
# Female  1000  895-03-6665      C  Yangon       Normal  Sports and travel
# Male     999  898-04-2717      C  Yangon       Normal  Sports and travel
#
#         Unitprice  Quantity    Tax    Total      Date   Time  Payment   cogs  \
# Gender
# Female      99.73        10  49.65  1042.65  3/9/2019  20:59  Ewallet  993.0
# Male        99.96        10  49.49  1039.29  3/9/2019  20:59  Ewallet  989.8
#
#         gross_margin_percentage  gross_iincome  Rating
# Gender
# Female                 4.761905          49.65    10.0
# Male                   4.761905          49.49    10.0

# %%
df.loc[df['Productline']=="Health and beauty"]
# Out:
#       No    InvoiceID Branch       City Customertype  Gender  \
# 0      1  750-67-8428      A     Yangon       Member  Female
# 3      4  123-19-1176      A     Yangon       Member    Male
# 8      9  665-32-9167      A     Yangon       Member  Female
# 14    15  829-34-3910      A     Yangon       Normal  Female
# 16    17  656-95-9349      A     Yangon       Member  Female
# ..   ...          ...    ...        ...          ...     ...
# 983  984  148-41-7930      C  Naypyitaw       Normal    Male
# 986  987  764-44-8999      B   Mandalay       Normal  Female
# 987  988  552-44-5977      B   Mandalay       Member    Male
# 989  990  430-53-4718      B   Mandalay       Member    Male
# 995  996  233-67-5758      C  Naypyitaw       Normal    Male
#
#            Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0    Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 3    Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# ...

# %%
df.loc[df['Gender']=="Female"]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 6       7  355-53-5943      A     Yangon       Member  Female
# 7       8  315-22-5665      C  Naypyitaw       Normal  Female
# 8       9  665-32-9167      A     Yangon       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 990   991  886-18-2897      A     Yangon       Normal  Female
# 991   992  602-16-6955      B   Mandalay       Normal  Female
# 994   995  652-49-6720      C  Naypyitaw       Member  Female
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.loc[df['Productline']=="Food and beverages"]
# Out:
#       No    InvoiceID Branch       City Customertype  Gender  \
# 9     10  692-92-5582      B   Mandalay       Member  Female
# 13    14  252-56-2699      A     Yangon       Normal    Male
# 18    19  329-62-1586      A     Yangon       Normal    Male
# 28    29  145-94-9061      B   Mandalay       Normal  Female
# 34    35  183-56-6882      C  Naypyitaw       Member  Female
# ..   ...          ...    ...        ...          ...     ...
# 977  978  518-71-6847      B   Mandalay       Member    Male
# 979  980  151-33-7434      B   Mandalay       Normal  Female
# 980  981  728-47-9078      C  Naypyitaw       Member    Male
# 990  991  886-18-2897      A     Yangon       Normal  Female
# 997  998  727-02-1313      A     Yangon       Member    Male
#
#             Productline  Unitprice  Quantity      Tax     Total       Date  \
# 9    Food and beverages      54.84         3   8.2260  172.7460  2/20/2019
# 13   Food and beverages      43.19        10  21.5950  453.4950   2/7/2019
# ...

# %%
df['Total'].loc[df['City']=="Yangon"]
# Out:
# 0      548.9715
# 2      340.5255
# 3      489.0480
# 4      634.3785
# 6      433.6920
#          ...
# 990    296.9400
# 992    121.8630
# 997     33.4320
# 998     69.1110
# 999    649.2990
# Name: Total, Length: 340, dtype: float64

# %%
df['Total'].loc[df['City']=="Yangon"].max()
# Out:
# 1039.29

# %%
df['gross_iincome'].loc[df['Productline']=="Home and lifestyle"]
# Out:
# 2      16.2155
# 7      36.7800
# 19      4.0300
# 22      3.3200
# 25     21.0360
#         ...
# 967    12.1515
# 971    12.9185
# 973    12.0120
# 996    48.6900
# 998     3.2910
# Name: gross_iincome, Length: 160, dtype: float64

# %%
df['gross_iincome'].loc[df['Productline']=="Home and lifestyle"].mean()
# Out:
# 16.03033125

# %%
x=df['gross_iincome'].loc[df['Productline']=="Home and lifestyle"]

# %%
print(x)
# Out:
# 2      16.2155
# 7      36.7800
# 19      4.0300
# 22      3.3200
# 25     21.0360
#         ...
# 967    12.1515
# 971    12.9185
# 973    12.0120
# 996    48.6900
# 998     3.2910
# Name: gross_iincome, Length: 160, dtype: float64

# %%
df.loc[(df['Productline'] == "Health and beauty") & (df['Gender'] == "Male") ]
# Out:
#       No    InvoiceID Branch       City Customertype Gender  \
# 3      4  123-19-1176      A     Yangon       Member   Male
# 21    22  371-85-5789      B   Mandalay       Normal   Male
# 29    30  848-62-7243      A     Yangon       Normal   Male
# 33    34  595-11-5460      A     Yangon       Normal   Male
# 44    45  617-15-4209      C  Naypyitaw       Member   Male
# ..   ...          ...    ...        ...          ...    ...
# 981  982  809-46-1866      A     Yangon       Normal   Male
# 983  984  148-41-7930      C  Naypyitaw       Normal   Male
# 987  988  552-44-5977      B   Mandalay       Member   Male
# 989  990  430-53-4718      B   Mandalay       Member   Male
# 995  996  233-67-5758      C  Naypyitaw       Normal   Male
#
#            Productline  Unitprice  Quantity      Tax     Total       Date  \
# 3    Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 21   Health and beauty      87.98         3  13.1970  277.1370   3/5/2019
# ...

# %%
x=df.loc[(df['Productline'] == "Health and beauty") & (df['Gender'] == "Male") ]

# %%
x.head()
# Out:
#     No    InvoiceID Branch       City Customertype Gender        Productline  \
# 3    4  123-19-1176      A     Yangon       Member   Male  Health and beauty
# 21  22  371-85-5789      B   Mandalay       Normal   Male  Health and beauty
# 29  30  848-62-7243      A     Yangon       Normal   Male  Health and beauty
# 33  34  595-11-5460      A     Yangon       Normal   Male  Health and beauty
# 44  45  617-15-4209      C  Naypyitaw       Member   Male  Health and beauty
#
#     Unitprice  Quantity      Tax     Total       Date   Time      Payment  \
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 21      87.98         3  13.1970  277.1370   3/5/2019  10:40      Ewallet
# 29      24.89         9  11.2005  235.2105  3/15/2019  15:36         Cash
# 33      96.58         2   9.6580  202.8180  3/15/2019  10:12  Credit card
# 44      15.37         2   1.5370   32.2770  3/16/2019  19:47         Cash
#
# ...

# %%
x["Gender"].count()
# Out:
# 88

# %%
df.loc[(df['Productline'] == "Health and beauty") & (df['Gender']== "Female") ]
# Out:
#       No    InvoiceID Branch       City Customertype  Gender  \
# 0      1  750-67-8428      A     Yangon       Member  Female
# 8      9  665-32-9167      A     Yangon       Member  Female
# 14    15  829-34-3910      A     Yangon       Normal  Female
# 16    17  656-95-9349      A     Yangon       Member  Female
# 38    39  333-73-7901      C  Naypyitaw       Normal  Female
# ..   ...          ...    ...        ...          ...     ...
# 927  928  397-25-8725      A     Yangon       Member  Female
# 936  937  433-08-7822      C  Naypyitaw       Normal  Female
# 938  939  131-70-8179      A     Yangon       Member  Female
# 968  969  605-03-2706      A     Yangon       Normal  Female
# 986  987  764-44-8999      B   Mandalay       Normal  Female
#
#            Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0    Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 8    Health and beauty      36.26         2   3.6260   76.1460  1/10/2019
# ...

# %%
df.loc[(df['Productline'] == "Health and beauty") & (df['Gender'] == "Male") ].count()
# Out:
# No                         88
# InvoiceID                  88
# Branch                     88
# City                       88
# Customertype               88
# Gender                     88
# Productline                88
# Unitprice                  88
# Quantity                   88
# Tax                        88
# Total                      88
# Date                       88
# Time                       88
# Payment                    88
# cogs                       88
# gross_margin_percentage    88
# gross_iincome              88
# Rating                     88
# dtype: int64

# %%
df.loc[(df['Productline'] == "Fashion accessories") & (df['Gender'] == "Female") | (df['Productline'] == "Sports and travel") ].count()
# Out:
# No                         262
# InvoiceID                  262
# Branch                     262
# City                       262
# Customertype               262
# Gender                     262
# Productline                262
# Unitprice                  262
# Quantity                   262
# Tax                        262
# Total                      262
# Date                       262
# Time                       262
# Payment                    262
# cogs                       262
# gross_margin_percentage    262
# gross_iincome              262
# Rating                     262
# dtype: int64
