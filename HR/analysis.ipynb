# %% [markdown]
# <a href="https://colab.research.google.com/github/JUMAAMOS/Business-Analytics-Python/blob/main/HR/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HR Analytics.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.loc[df['EducationField']=="Life Sciences"]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1454   45        No      Travel_Rarely        374                   Sales
# 1455   40        No      Travel_Rarely       1322  Research & Development
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1458   35        No      Travel_Rarely        287  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.loc[df['EducationField']=="Life Sciences"].count()
# Out:
# Age                         606
# Attrition                   606
# BusinessTravel              606
# DailyRate                   606
# Department                  606
# DistanceFromHome            606
# Education                   606
# EducationField              606
# EmployeeCount               606
# EmployeeNumber              606
# EnvironmentSatisfaction     606
# Gender                      606
# HourlyRate                  606
# JobInvolvement              606
# JobLevel                    606
# JobRole                     606
# JobSatisfaction             606
# MaritalStatus               606
# MonthlyIncome               606
# MonthlyRate                 606
# NumCompaniesWorked          606
# Over18                      606
# OverTime                    606
# PercentSalaryHike           606
# PerformanceRating           606
# RelationshipSatisfaction    606
# StandardHours               606
# StockOptionLevel            606
# TotalWorkingYears           606
# ...

# %%
df.loc[df['Department']=="Sales"]
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102      Sales
# 18     53        No      Travel_Rarely       1219      Sales
# 21     36       Yes      Travel_Rarely       1218      Sales
# 27     42        No      Travel_Rarely        691      Sales
# 29     46        No      Travel_Rarely        705      Sales
# ...   ...       ...                ...        ...        ...
# 1454   45        No      Travel_Rarely        374      Sales
# 1461   50       Yes      Travel_Rarely        410      Sales
# 1462   39        No      Travel_Rarely        722      Sales
# 1464   26        No      Travel_Rarely       1167      Sales
# 1468   49        No  Travel_Frequently       1023      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 18                   2          4  Life Sciences              1
# ...

# %%
df.loc[df['Department']=="Sales"].max()
# Out:
# Age                                           60
# Attrition                                    Yes
# BusinessTravel                     Travel_Rarely
# DailyRate                                   1499
# Department                                 Sales
# DistanceFromHome                              29
# Education                                      5
# EducationField                  Technical Degree
# EmployeeCount                                  1
# EmployeeNumber                              2065
# EnvironmentSatisfaction                        4
# Gender                                      Male
# HourlyRate                                   100
# JobInvolvement                                 4
# JobLevel                                       5
# JobRole                     Sales Representative
# JobSatisfaction                                4
# MaritalStatus                             Single
# MonthlyIncome                              19847
# ...

# %%
df.loc[(df['Department'] == "Research & Development" ) & (df['EducationField'] == "Medical") ]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 4      27        No      Travel_Rarely        591  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 13     34        No      Travel_Rarely       1346  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1463   31        No         Non-Travel        325  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.loc[(df['BusinessTravel']=="Travel_Rarely") & (df['Department']=="Sales")]
# Out:
#       Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0      41       Yes  Travel_Rarely       1102      Sales                 1
# 18     53        No  Travel_Rarely       1219      Sales                 2
# 21     36       Yes  Travel_Rarely       1218      Sales                 9
# 27     42        No  Travel_Rarely        691      Sales                 8
# 29     46        No  Travel_Rarely        705      Sales                 2
# ...   ...       ...            ...        ...        ...               ...
# 1453   36        No  Travel_Rarely       1120      Sales                11
# 1454   45        No  Travel_Rarely        374      Sales                20
# 1461   50       Yes  Travel_Rarely        410      Sales                28
# 1462   39        No  Travel_Rarely        722      Sales                24
# 1464   26        No  Travel_Rarely       1167      Sales                 5
#
# ...

# %%
df['Age'].loc[(df['Department']=="Research & Development") & (df['EducationField']=="Medical")]>50
# Out:
# 4       False
# 6        True
# 9       False
# 10      False
# 13      False
#         ...
# 1460    False
# 1463    False
# 1465    False
# 1466    False
# 1469    False
# Name: Age, Length: 363, dtype: bool
